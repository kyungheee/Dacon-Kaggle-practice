# %%
import os
import torch
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
#하이퍼 파라미터 튜닝

CFG = {
    'IMG_SIZE':128, #이미지 사이즈
    'EPOCHS':50, #에포크
    'LEARNING_RATE':2e-2, #학습률
    'BATCH_SIZE':12, #배치사이즈
    'SEED':41, #시드
}

# %%
import random
import numpy as np

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED'])

# %%
import pandas as pd
label_df = pd.read_csv('/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/train.csv')
label_df.head()
# Out:
#   file_name label
# 0   001.png  10-2
# 1   002.png  10-1
# 2   003.png     3
# 3   004.png     8
# 4   005.png     9

# %%
label_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  858 non-null    object
#  1   label      858 non-null    object
# dtypes: object(2)
# memory usage: 13.5+ KB

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 모델링을 하기 위해 label을 정수형으로 수정

# %%
label_df['label'][label_df['label']=='10-1'] = 10
label_df['label'][label_df['label']=='10-2'] = 0
label_df['label'] = label_df['label'].apply(lambda x : int(x))

# %%
label_df
# Out:
#     file_name  label
# 0     001.png      0
# 1     002.png     10
# 2     003.png      3
# 3     004.png      8
# 4     005.png      9
# ..        ...    ...
# 853   854.png      9
# 854   855.png      1
# 855   856.png      4
# 856   857.png     10
# 857   858.png      7
#
# [858 rows x 2 columns]

# %%
label_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  858 non-null    object
#  1   label      858 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# 데이터 이미지의 local adress 와 label값을 list에 저장

# %%
from glob import glob

def get_train_data(data_dir):
    img_path_list = []
    label_list = []

    # get image path
    img_path_list.extend(glob(os.path.join(data_dir, '*.png')))
    img_path_list.sort(key=lambda x:int(x.split('/')[-1].split('.')[0]))
    print('wow',img_path_list)

    # get label
    # label_df = pd.read_csv(data_dir+'/train.csv')
    label_list.extend(label_df['label'])
    print('wow2', label_list)

    return img_path_list, label_list

def get_test_data(data_dir):
    img_path_list = []

    # get image path
    img_path_list.extend(glob(os.path.join(data_dir, '*.png')))
    img_path_list.sort(key=lambda x:int(x.split('/')[-1].split('.')[0]))
    print(img_path_list)

    return img_path_list

# %%
all_img_path, all_label = get_train_data('/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train')
test_img_path = get_test_data('/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test')
# Out:
# wow ['/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/001.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/002.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/003.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/004.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/005.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/006.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/007.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/008.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/009.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/010.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/011.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/012.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/013.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/014.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/015.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/016.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/017.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/018.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/019.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/020.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/021.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/022.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/023.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/024.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/025.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/026.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/027.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/028.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/029.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/030.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/train/031.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudD ...
# wow2 [0, 10, 3, 8, 9, 9, 8, 0, 5, 5, 9, 2, 4, 10, 9, 2, 0, 7, 4, 2, 6, 10, 10, 6, 10, 5, 6, 3, 0, 8, 1, 2, 8, 2, 5, 10, 6, 1, 1, 4, 4, 0, 7, 4, 4, 9, 0, 9, 8, 2, 6, 10, 9, 5, 3, 3, 6, 2, 1, 2, 10, 0, 5, 3, 4, 6, 6, 7, 2, 8, 6, 0, 9, 0, 6, 3, 8, 0, 1, 7, 6, 1, 6, 9, 6, 7, 3, 10, 3, 10, 10, 4, 3, 1, 6, 6, 2, 6, 9, 7, 9, 4, 2, 7, 10, 4, 3, 2, 6, 4, 3, 10, 9, 2, 7, 0, 8, 10, 5, 5, 6, 0, 9, 0, 7, 6, 2, 0, 1, 5, 5, 5, 4, 6, 4, 9, 10, 6, 1, 7, 2, 9, 4, 3, 1, 4, 3, 6, 2, 10, 7, 10, 1, 4, 1, 6, 4, 5, 5, 2, 5, 6, 9, 8, 7, 4, 3, 7, 1, 9, 10, 2, 6, 7, 3, 7, 6, 9, 2, 2, 10, 8, 8, 9, 8, 4, 4, 5, 4, 10, 10, 6, 1, 6, 4, 1, 4, 6, 1, 4, 6, 2, 3, 8, 1, 5, 9, 10, 9, 3, 7, 1, 4, 8, 2, 10, 6, 5, 7, 10, 4, 1, 5, 7, 4, 2, 7, 1, 9, 1, 8, 4, 6, 0, 4, 6, 2, 3, 7, 2, 2, 1, 0, 1, 2, 3, 8, 2, 1, 10, 1, 5, 2, 5, 7, 6, 8, 4, 1, 1, 3, 5, 8, 8, 0, 7, 9, 10, 9, 3, 4, 2, 6, 0, 9, 5, 5, 7, 5, 7, 2, 8, 6, 0, 1, 0, 2, 9, 7, 9, 0, 2, 5, 0, 10, 4, 10, 9, 5, 4, 2, 8, 4, 2, 8, 2, 8, 3, 2, 6, 8, 10, 10, 3, 8, 7, 3, 2, 5, 6, 2, 8, 8, 4, 9, 4, 2, 6, 10, 7, 1, 9, 8, 0, 2, 5, 9, 5, 7, 7, 8, 0, 4, 5, 10, 3, 5, 8, 8, 4, 8, 8, 3, 9, 8, 5, 3, 4, 3, 0, 1, 6, 10, 6, 8, 10, 5, 1, 5, 7, 10, 10, 0, 9, 6, 4, 10, 6, 9, 2, 3, 8, 2, 3, 4, 6, 9, 8, 10, 10, 8, 5, 9, 7, 9, 1, 1, 5, 2, 1, 5, 10, 10, 6, 1, 7, 2, 4, 0, 9, 2, 10, 6, 7, 7, 1, 6, 5, 2, 3, 2, 9, 10, 1, 2, 7, 7, 0, 1, 7, 5, 8, 9, 7, 8, 8, 2, 10, 9, 3, 8, 5, 4, 9, 3, 7, 4, 4, 5, 7, 8, 8, 10, 6, 10, 8, 1, 7, 9, 6, 10, 7, 7, 7, 10, 7, 7, 2, 5, 8, 1, 1, 10, 6, 0, 7, 0, 1, 5, 4, 1, 7, 7, 2, 7, 2, 4, 3, 1, 4, 9, 10, 1, 6, 3, 8, 4, 6, 9, 7, 3, 2, 10, 4, 10, 1, 3, 5, 1, 4, 5, 9, 5, 5, 2, 0, 10, 4, 7, 5, 3, 1, 5, 8, 9, 6, 1, 4, 4, 7, 3, 1, 2, 5, 9, 6, 1, 9, 6, 3, 8, 4, 7, 6, 0, 8, 10, 5, 10, 2, 6, 6, 4, 5, 9, 3, 9, 8, 8, 9, 4, 9, 6, 1, 4, 6, 10, 10, 1, 7, 1, 0, 3, 1, 6, 10, 2, 0, 3, 9, 2, 0, 3, 0, 4, 0, 9, 1, 2, 3, 9, 5, 1, 6, 1, 0, 3, 10, 1, 9, 3, 10, 10, 1, 8, 10, 2, 3, 8, 10, 5, 8, 2, 8, 2, 9, 5, 6, 4, 9, 3, 0, 2, 7, 3, 1, 10, 0, 6, 1, 8, 6, 3, 7, 8, 9, 9, 1, 7, 8, 1, 9, 8, 9, 5, 7, 4, 4, 1, 5, 7, 5, 6, 8, 10, 4, 8, 9, 7, 2, 7, 4, 9, 6, 1, 9, 0, 9, 2, 1, 3, 0, 3, 2, 6, 5, 5, 1, 8, 8, 4, 7, 3, 0, 5, 4, 3, 7, 10, 5, 9, 8, 6, 5, 10, 7, 6, 3, 7, 7, 7, 8, 8, 6, 5, 5, 4, 4, 9, 0, 8, 2, 10, 3, 6, 6, 0, 7, 7, 3, 4, 10, 6, 9, 3, 9, 7, 8, 2, 3, 2, 0, 5, 9, 9, 2, 4, 7, 8, 0, 0, 3, 0, 3, 6, 3, 10, 0, 8, 5, 2, 1, 4, 2, 10, 10, 8, 10, 6, 1, 3, 1, 0, 9, 5, 5, 10, 8, 5, 6, 5, 7, 4, 10, 4, 8, 1, 4, 5, 1, 2, 10, 2, 2, 3, 1, 3, 1, 8, 4, 2, 3, 5, 8, 1, 4, 4, 5, 9, 3, 3, 2, 7, 4, 8, 3, 7, 6, 0, 7, 3, 4, 7, 2, 4, 2, 7, 5, 1, 10, 2, 9, 0, 9, 3, 10, 10, 3, 3, 5, 7, 7, 1, 6, 3, 7, 2, 8, 10, 0, 5, 10, 3, 4, 9, 5, 4, 8, 3, 2, 0, 5, 0, 9, 1, 4, 10, 7]
# ['/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/001.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/002.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/003.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/004.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/005.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/006.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/007.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/008.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/009.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/010.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/011.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/012.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/013.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/014.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/015.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/016.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/017.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/018.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/019.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/020.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/021.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/022.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/023.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/024.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/025.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/026.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/027.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/028.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/029.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/030.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/data/hand_dataset/test/031.png', '/Users/kyunghee/Library/Mobile Documents/com~apple~CloudDocs/깃허브 repo/Dacon-Kaggle-practice/ ...

# %%
all_label[0:5]
# Out:
# [0, 10, 3, 8, 9]

# %% [markdown]
# # CustomDataset

# %%
import torchvision.datasets as datasets 
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader, Dataset

class CustomDataset(Dataset):
    def __init__(self, img_path_list, label_list, train_mode = True, transforms = None):
        self.transforms = transforms
        self.train_mode = train_mode
        self.img_path_list = img_path_list
        self.label_list = label_list

    def __getitem__(self, index):
        img_path = self.img_path_list[index]
        # get image data
        image = cv2.imread(img_path)
        if self.transforms is not None:
            image = self.transforms(image)

        if self.train_mode:
            label = self.label_list[index]
            return image, label
        else:
            return image
        
    def __len__(self):
        return len(self.img_path_list)

# %% [markdown]
# ### Train/Validation Split

# %%
train_len = int(len(all_img_path)*0.75)
vali_len = int(len(all_img_path)*0.25)

train_img_path = all_img_path[:train_len]
train_label = all_label[:train_len]

vali_img_path = all_img_path[train_len:]
vali_label = all_label[train_len:]

# %%
print('train set 길이 : ', train_len)
print('validation set 길이 : ', vali_len)
# Out:
# train set 길이 :  643
# validation set 길이 :  214

# %%
train_transforms = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize([CFG['IMG_SIZE'], CFG['IMG_SIZE']]), # 이미지 사이즈 변형
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.5,0.5,0.5), std=(0.5,0.5,0.5)) # 이미지 정규화
])

test_transforms = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize([CFG['IMG_SIZE'], CFG['IMG_SIZE']]), # 이미지 사이즈 변형
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.5,0.5,0.5), std=(0.5,0.5,0.5)) # 이미지 정규화
])

# %% [markdown]
# # DataLoader
#
# 데이터 로더를 통해 데이터셋의 전체 데이터가 배치 사이즈로 나뉘게 된다.
# 만들었던 데이터셋을 인풋으로 넣어주면 여러 옵션(데이터 묶기, 섞기, 알아서 병렬처리)을 통해 batch를 만들어냄

# %%
# get data loader 

train_dataset = CustomDataset(train_img_path, train_label, train_mode = True, transforms= train_transforms)
# 배치 만들기
train_loader = DataLoader(train_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=True, num_workers=0)

# validation에서도 적용
vali_dataset = CustomDataset(vali_img_path, vali_label, train_mode = True, transforms=test_transforms)
vali_loader = DataLoader(vali_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
train_batches = len(train_loader)
vali_batches = len(vali_loader)

print('total train imgs : ',train_len, '/ total train batches : ', train_batches)
print('total valid imgs : ',vali_len, '/ total valid batches : ', vali_batches)
# Out:
# total train imgs :  643 / total train batches :  54
# total valid imgs :  214 / total valid batches :  18

# %% [markdown]
# ## 모델 불러오기

# %%
from torchvision import models
from torchvision.models import efficientnet_b3 as efficientnet

model = models.efficientnet_b3(pretrained=False)
# Out:
# /Users/kyunghee/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/kyunghee/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
model.classifier
# Out:
# Sequential(
#   (0): Dropout(p=0.3, inplace=True)
#   (1): Linear(in_features=1536, out_features=1000, bias=True)
# )

# %% [markdown]
# ## 모델학습

# %%
import torch.optim as optim

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = None

# %%
from tqdm import tqdm



def train(model, optimizer, train_loader, scheduler, device):
    model.to(device)
    n = len(train_loader)

    ## LOSS FUNCTION 정의 
    best_acc = 0

    for epoch in range(1, CFG["EPOCHS"]+1):
        model.train()
        running_loss = 0.0

        for img, label in tqdm(iter(train_loader)):
            img, label = img.to(device), label.to(device)
            optimizer.zero_grad()

            # data -> model -> output
            logit = model(img)
            loss = criterion(logit, label)

            # 역전파
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        print('[%d] train loss : %.10f' % (epoch, running_loss/len(train_loader)))


        if scheduler is not None:
            scheduler.step()

        # validation 평가
        model.eval()
        vali_loss = 0.0
        correct = 0
        with torch.no_grad():
            for img, label in tqdm(iter(vali_loader)):
                img, label = img.to(device), label.to(device)

                logit = model(img)
                vali_loss += criterion(logit, label)
                pred = logit.argmax(dim=1, keepdim=True)
                correct += pred.eq(label.view_as(pred)).sum().item()
        vali_acc = 100 * correct /len(vali_loader.dataset)
        print('Vail set: Loss: {:.4f}, Accuracy: {}/{} ( {:.0f}%)\n'.format(vali_loss / len(vali_loader), correct, len(vali_loader.dataset), 100* correct/len(vali_loader.dataset)))

        # best model 저장
        if best_acc < vali_acc:
            best_acc = vali_acc
            torch.save(model.state_dict(), './saved/best_model.pth')
            print('model saved.')

# %%
train(model, optimizer, train_loader, scheduler, device)
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
# 100%|██████████| 54/54 [02:56<00:00,  3.28s/it]
# [1] train loss : 4.0073316186
# 100%|██████████| 18/18 [00:16<00:00,  1.09it/s]
# Vail set: Loss: 17.1208, Accuracy: 19/215 ( 9%)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 train(model, optimizer, train_loader, scheduler, device)
#
# Cell In[21], line 53, in train(model, optimizer, train_loader, scheduler, device)
#      51 if best_acc < vali_acc:
#      52     best_acc = vali_acc
# ---> 53     torch.save(model.state_dict(), './saved/best_model.pth')
#      54     print('model saved.')
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:618, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     615 _check_save_filelike(f)
#     617 if _use_new_zipfile_serialization:
# --> 618     with _open_zipfile_writer(f) as opened_zipfile:
#     619         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620         return
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:492, in _open_zipfile_writer(name_or_buffer)
#     490 else:
#     491     container = _open_zipfile_writer_buffer
# --> 492 return container(name_or_buffer)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:463, in _open_zipfile_writer_file.__init__(self, name)
#     461     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     462 else:
# --> 463     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ./saved does not exist.
